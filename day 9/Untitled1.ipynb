# %%
import pandas as pd

# %%
import glob

# %%
import os

# %%
path='harsh'

# %%
all_files = glob.glob(path + "/*.csv")

# %%
all_files
# Out:
# ['harsh/Road Accident Data_304.csv', 'harsh/Road Accident Data_294.csv']

# %%
for i in all_files:
 df=pd.read_csv(i)

# %%
df
# Out:
#     Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0        BS0293001    21-04-2022   Wednesday      Give way or uncontrolled
# 1        BS0293002    28-04-2022   Wednesday  Data missing or out of range
# 2        BS0293003    21-04-2022   Wednesday  Data missing or out of range
# 3        BS0293004    01-05-2022    Saturday  Data missing or out of range
# 4        BS0293005    03-05-2022      Monday      Give way or uncontrolled
# ..             ...           ...         ...                           ...
# 995      BS0293996    24-01-2022      Sunday      Give way or uncontrolled
# 996      BS0293997    19-01-2022     Tuesday      Give way or uncontrolled
# 997      BS0293998    04-01-2022      Monday  Data missing or out of range
# 998      BS0293999    22-01-2022      Friday  Data missing or out of range
# 999      BS0294000    22-01-2022      Friday           Auto traffic signal
#
# ...
