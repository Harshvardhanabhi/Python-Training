# %%
import pandas as pd

# %%
import os
import glob

# %%
# csv =glob.glob("*.csv")

directory_path = "/home/developer/Desktop" # Replace with your directory
csv = glob.glob(os.path.join(directory_path, "**/*.csv"), recursive=True)

# %%
csv
# Out:
# ['/home/developer/Desktop/pandasfile/Road Accident Data_304.csv',
#  '/home/developer/Desktop/pandasfile/Road Accident Data_300.csv',
#  '/home/developer/Desktop/pandasfile/Road Accident Data_294.csv']

# %%
l1=[]

# %%
for i in csv:
    df= pd.read_csv(i)
    l1.append(df)

# %%
pd.concat(l1,axis=0)
# Out:
#     Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0        BS0303001    27-06-2022      Sunday      Give way or uncontrolled
# 1        BS0303002    27-07-2022     Tuesday  Data missing or out of range
# 2        BS0303003    25-07-2022      Sunday      Give way or uncontrolled
# 3        BS0303004    06-08-2022      Friday  Data missing or out of range
# 4        BS0303005    19-07-2022      Monday      Give way or uncontrolled
# ..             ...           ...         ...                           ...
# 995      BS0293996    24-01-2022      Sunday      Give way or uncontrolled
# 996      BS0293997    19-01-2022     Tuesday      Give way or uncontrolled
# 997      BS0293998    04-01-2022      Monday  Data missing or out of range
# 998      BS0293999    22-01-2022      Friday  Data missing or out of range
# 999      BS0294000    22-01-2022      Friday           Auto traffic signal
#
# ...
