# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('fake_property_data.json')

# %%
df.head()
# Out:
#                                       Property_Title  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478
#
#                                              Address Reviewed_Status  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...        Reviewed
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...            Null
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...          Closed
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478          Closed
#
#   Most_Recent_Status       Source   Market Occupancy          Flood  \
# 0             Closed     Internal  Chicago      None           None
# 1          Cancelled  Auction.com   Dallas      None  Minimal Flood
# ...

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df2 = pd.read_excel('Field Config.xlsx')

# %%
df2
# Out:
#                Column Name Target Table
# 0           Property_Title     property
# 1                  Address     property
# 2          Reviewed_Status        Leads
# 3       Most_Recent_Status        Leads
# 4                   Source        Leads
# ..                     ...          ...
# 61          Selling_Reason        leads
# 62  Seller_Retained_Broker        leads
# 63                HOA_Flag          HOA
# 64          Final_Reviewer        leads
# 65          School_Average     property
#
# [66 rows x 2 columns]

# %%
df.describe(include='all').T
# Out:
#                           count unique  \
# Property_Title            10000  10000
# Address                   10000  10000
# Reviewed_Status           10000     10
# Most_Recent_Status        10000     12
# Source                    10000      8
# Market                    10000      8
# Occupancy                  6718      2
# Flood                      6591      2
# Street_Address            10000  10000
# City                      10000   7632
# State                     10000     59
# Zip                     10000.0    NaN
# Property_Type             10000      5
# Highway                    6602      2
# Train                      6669      2
# Tax_Rate                10000.0    NaN
# SQFT_Basement           10000.0    NaN
# HTW                        6599      2
# Pool                       6585      2
# Commercial                 6716      2
# Water                      6697      2
# Sewage                     6748      2
# Year_Built              10000.0    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Property_Title          10000 non-null  object
#  1   Address                 10000 non-null  object
#  2   Reviewed_Status         10000 non-null  object
#  3   Most_Recent_Status      10000 non-null  object
#  4   Source                  10000 non-null  object
#  5   Market                  10000 non-null  object
#  6   Occupancy               6718 non-null   object
#  7   Flood                   6591 non-null   object
#  8   Street_Address          10000 non-null  object
#  9   City                    10000 non-null  object
#  10  State                   10000 non-null  object
#  11  Zip                     10000 non-null  int64
#  12  Property_Type           10000 non-null  object
#  13  Highway                 6602 non-null   object
# ...

# %%
to_drop=df.isnull().sum()*100/len(df)

# %%
to_drop
# Out:
# Property_Title             0.00
# Address                    0.00
# Reviewed_Status            0.00
# Most_Recent_Status         0.00
# Source                     0.00
# Market                     0.00
# Occupancy                 32.82
# Flood                     34.09
# Street_Address             0.00
# City                       0.00
# State                      0.00
# Zip                        0.00
# Property_Type              0.00
# Highway                   33.98
# Train                     33.31
# Tax_Rate                   0.00
# SQFT_Basement              0.00
# HTW                       34.01
# Pool                      34.15
# Commercial                32.84
# Water                     33.03
# Sewage                    32.52
# Year_Built                 0.00
# SQFT_MU                    0.00
# SQFT_Total                 0.00
# Parking                   24.89
# Bed                        0.00
# Bath                       0.00
# BasementYesNo             33.65
# ...

# %%
df.columns
# Out:
# Index(['Property_Title', 'Address', 'Reviewed_Status', 'Most_Recent_Status',
#        'Source', 'Market', 'Occupancy', 'Flood', 'Street_Address', 'City',
#        'State', 'Zip', 'Property_Type', 'Highway', 'Train', 'Tax_Rate',
#        'SQFT_Basement', 'HTW', 'Pool', 'Commercial', 'Water', 'Sewage',
#        'Year_Built', 'SQFT_MU', 'SQFT_Total', 'Parking', 'Bed', 'Bath',
#        'BasementYesNo', 'Layout', 'Net_Yield', 'IRR', 'Rent_Restricted',
#        'Neighborhood_Rating', 'Latitude', 'Longitude', 'Subdivision', 'Taxes',
#        'Selling_Reason', 'Seller_Retained_Broker', 'Final_Reviewer',
#        'School_Average', 'Valuation', 'HOA', 'Rehab'],
#       dtype='object')

# %%
cols_to_drop
# Out:
# Index(['Occupancy', 'Flood', 'Highway', 'Train', 'HTW', 'Pool', 'Commercial',
#        'Water', 'Sewage', 'BasementYesNo', 'Rent_Restricted',
#        'Seller_Retained_Broker'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 45)

# %%
cols_to_drop = to_drop[to_drop > 30].index

# %%
filter_df = df.drop(columns=cols_to_drop, errors='ignore')

# %%
filter_df
# Out:
#                                          Property_Title  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3     86578 Lawson Park Suite 865, South Brianfurt, ...
# 4          309 Roy Brook Apt. 282, Lake Scott, FL 84478
# ...                                                 ...
# 9995           139 Fisher Spur, North Brandon, WA 23114
# 9996       275 Gutierrez Views, Lake Victoria, WY 63275
# 9997        341 Vanessa Harbor, North Melissa, CT 39313
# 9998  78647 Brittany Village, North Ethanborough, NY...
# 9999  5461 Nichols Throughway, East Crystalborough, ...
#
#                                                 Address Reviewed_Status  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...        Reviewed
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...            Null
# ...

# %%
new_corr= filter_df.select_dtypes(include=['int64' and 'float64'])

# %%
new_corr.corr()
# Out:
#                 Tax_Rate  Net_Yield       IRR  Latitude  Longitude  \
# Tax_Rate        1.000000   0.006480 -0.008752 -0.033988  -0.008615
# Net_Yield       0.006480   1.000000 -0.014106  0.009860  -0.007266
# IRR            -0.008752  -0.014106  1.000000  0.006101  -0.002670
# Latitude       -0.033988   0.009860  0.006101  1.000000  -0.010480
# Longitude      -0.008615  -0.007266 -0.002670 -0.010480   1.000000
# School_Average -0.001242   0.008341  0.005526  0.025118   0.008675
#
#                 School_Average
# Tax_Rate             -0.001242
# Net_Yield             0.008341
# IRR                   0.005526
# Latitude              0.025118
# Longitude             0.008675
# School_Average        1.000000

# %%
filter_df.isnull().sum()
# Out:
# Property_Title            0
# Address                   0
# Reviewed_Status           0
# Most_Recent_Status        0
# Source                    0
# Market                    0
# Street_Address            0
# City                      0
# State                     0
# Zip                       0
# Property_Type             0
# Tax_Rate                  0
# SQFT_Basement             0
# Year_Built                0
# SQFT_MU                   0
# SQFT_Total                0
# Parking                2489
# Bed                       0
# Bath                      0
# Layout                 2554
# Net_Yield                 0
# IRR                       0
# Neighborhood_Rating       0
# Latitude                  0
# Longitude                 0
# Subdivision               0
# Taxes                     0
# Selling_Reason         2489
# Final_Reviewer            0
# School_Average            0
# Valuation                 0
# HOA                       0
# Rehab                     0
# ...

# %%
mode_value= filter_df['Parking'].mode()

# %%
mode_value
# Out:
# 0    Street
# Name: Parking, dtype: object

# %%
filter_df['Parking'].fillna(mode_value, inplace=True)

# %%
mode_value2= filter_df['Selling_Reason'].mode()[0]
mode_value2
# Out:
# 'Investor Sale'

# %%
filter_df['Selling_Reason'].fillna(mode_value2, inplace=True)

# %%
mode_value3= filter_df['Layout'].mode()[0]
mode_value3
# Out:
# 'Ranch'

# %%
filter_df['Layout'].fillna(mode_value3, inplace=True)

# %%
filter_df.isnull().sum()
# Out:
# Property_Title            0
# Address                   0
# Reviewed_Status           0
# Most_Recent_Status        0
# Source                    0
# Market                    0
# Street_Address            0
# City                      0
# State                     0
# Zip                       0
# Property_Type             0
# Tax_Rate                  0
# SQFT_Basement             0
# Year_Built                0
# SQFT_MU                   0
# SQFT_Total                0
# Parking                2489
# Bed                       0
# Bath                      0
# Layout                    0
# Net_Yield                 0
# IRR                       0
# Neighborhood_Rating       0
# Latitude                  0
# Longitude                 0
# Subdivision               0
# Taxes                     0
# Selling_Reason            0
# Final_Reviewer            0
# School_Average            0
# Valuation                 0
# HOA                       0
# Rehab                     0
# ...

# %%
mode_value2= filter_df['Parking'].mode()[0]

# %%
mode_value2
# Out:
# 'Street'

# %%
filter_df['Parking'].fillna(mode_value2, inplace=True)

# %%
filter_df.isnull().sum()
# Out:
# Property_Title         0
# Address                0
# Reviewed_Status        0
# Most_Recent_Status     0
# Source                 0
# Market                 0
# Street_Address         0
# City                   0
# State                  0
# Zip                    0
# Property_Type          0
# Tax_Rate               0
# SQFT_Basement          0
# Year_Built             0
# SQFT_MU                0
# SQFT_Total             0
# Parking                0
# Bed                    0
# Bath                   0
# Layout                 0
# Net_Yield              0
# IRR                    0
# Neighborhood_Rating    0
# Latitude               0
# Longitude              0
# Subdivision            0
# Taxes                  0
# Selling_Reason         0
# Final_Reviewer         0
# School_Average         0
# Valuation              0
# HOA                    0
# Rehab                  0
# dtype: int64

# %%
filter_df.head()
# Out:
#                                       Property_Title  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478
#
#                                              Address Reviewed_Status  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...        Reviewed
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...            Null
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...          Closed
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478          Closed
#
#   Most_Recent_Status       Source   Market                Street_Address  \
# 0             Closed     Internal  Chicago  875 Davis Overpass Suite 394
# 1          Cancelled  Auction.com   Dallas    1159 Johnson Pass Apt. 567
# ...

# %%
filter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Property_Title       10000 non-null  object
#  1   Address              10000 non-null  object
#  2   Reviewed_Status      10000 non-null  object
#  3   Most_Recent_Status   10000 non-null  object
#  4   Source               10000 non-null  object
#  5   Market               10000 non-null  object
#  6   Street_Address       10000 non-null  object
#  7   City                 10000 non-null  object
#  8   State                10000 non-null  object
#  9   Zip                  10000 non-null  int64
#  10  Property_Type        10000 non-null  object
#  11  Tax_Rate             10000 non-null  float64
#  12  SQFT_Basement        10000 non-null  int64
#  13  Year_Built           10000 non-null  int64
#  14  SQFT_MU              10000 non-null  int64
# ...

# %%
filter_df.columns
# Out:
# Index(['Property_Title', 'Address', 'Reviewed_Status', 'Most_Recent_Status',
#        'Source', 'Market', 'Street_Address', 'City', 'State', 'Zip',
#        'Property_Type', 'Tax_Rate', 'SQFT_Basement', 'Year_Built', 'SQFT_MU',
#        'SQFT_Total', 'Parking', 'Bed', 'Bath', 'Layout', 'Net_Yield', 'IRR',
#        'Neighborhood_Rating', 'Latitude', 'Longitude', 'Subdivision', 'Taxes',
#        'Selling_Reason', 'Final_Reviewer', 'School_Average', 'Valuation',
#        'HOA', 'Rehab'],
#       dtype='object')

# %%
new = filter_df.select_dtypes(include=['int64' and 'float64'])

# %%
new.corr()
# Out:
#                 Tax_Rate  Net_Yield       IRR  Latitude  Longitude  \
# Tax_Rate        1.000000   0.006480 -0.008752 -0.033988  -0.008615
# Net_Yield       0.006480   1.000000 -0.014106  0.009860  -0.007266
# IRR            -0.008752  -0.014106  1.000000  0.006101  -0.002670
# Latitude       -0.033988   0.009860  0.006101  1.000000  -0.010480
# Longitude      -0.008615  -0.007266 -0.002670 -0.010480   1.000000
# School_Average -0.001242   0.008341  0.005526  0.025118   0.008675
#
#                 School_Average
# Tax_Rate             -0.001242
# Net_Yield             0.008341
# IRR                   0.005526
# Latitude              0.025118
# Longitude             0.008675
# School_Average        1.000000

# %%
filter_df.replace(' ',np.nan,inplace=True)

# %%
filter_df.replace('Null', np.nan, inplace=True)

# %%
filter_df.isnull().sum()
# Out:
# Property_Title            0
# Address                   0
# Reviewed_Status        1940
# Most_Recent_Status     1721
# Source                    0
# Market                 1245
# Street_Address            0
# City                      0
# State                     0
# Zip                       0
# Property_Type             0
# Tax_Rate                  0
# SQFT_Basement             0
# Year_Built                0
# SQFT_MU                   0
# SQFT_Total                0
# Parking                   0
# Bed                       0
# Bath                      0
# Layout                    0
# Net_Yield                 0
# IRR                       0
# Neighborhood_Rating       0
# Latitude                  0
# Longitude                 0
# Subdivision               0
# Taxes                     0
# Selling_Reason            0
# Final_Reviewer            0
# School_Average            0
# Valuation                 0
# HOA                       0
# Rehab                     0
# ...

# %%
filter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Property_Title       10000 non-null  object
#  1   Address              10000 non-null  object
#  2   Reviewed_Status      8060 non-null   object
#  3   Most_Recent_Status   8279 non-null   object
#  4   Source               10000 non-null  object
#  5   Market               8755 non-null   object
#  6   Street_Address       10000 non-null  object
#  7   City                 10000 non-null  object
#  8   State                10000 non-null  object
#  9   Zip                  10000 non-null  int64
#  10  Property_Type        10000 non-null  object
#  11  Tax_Rate             10000 non-null  float64
#  12  SQFT_Basement        10000 non-null  int64
#  13  Year_Built           10000 non-null  int64
#  14  SQFT_MU              10000 non-null  int64
# ...

# %%
mode_v= filter_df['Reviewed_Status'].mode()[0]

# %% [markdown]
# Reviewed_Status        1940
# Most_Recent_Status     1721
# Source                    0
# Market                 1245

# %%
filter_df['Reviewed_Status'].fillna(mode_v, inplace=True)

# %%
mode_= filter_df['Most_Recent_Status'].mode()[0]

# %%
filter_df['Most_Recent_Status'].fillna(mode_, inplace=True)

# %%
mode2_= filter_df['Market'].mode()[0]

# %%
filter_df['Market'].fillna(mode_v, inplace=True)

# %%
filter_df.isnull().sum()
# Out:
# Property_Title         0
# Address                0
# Reviewed_Status        0
# Most_Recent_Status     0
# Source                 0
# Market                 0
# Street_Address         0
# City                   0
# State                  0
# Zip                    0
# Property_Type          0
# Tax_Rate               0
# SQFT_Basement          0
# Year_Built             0
# SQFT_MU                0
# SQFT_Total             0
# Parking                0
# Bed                    0
# Bath                   0
# Layout                 0
# Net_Yield              0
# IRR                    0
# Neighborhood_Rating    0
# Latitude               0
# Longitude              0
# Subdivision            0
# Taxes                  0
# Selling_Reason         0
# Final_Reviewer         0
# School_Average         0
# Valuation              0
# HOA                    0
# Rehab                  0
# dtype: int64

# %%
filter_df.head()
# Out:
#                                       Property_Title  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478
#
#                                              Address Reviewed_Status  \
# 0  875 Davis Overpass Suite 394, South Kathrynsid...          Closed
# 1  1159 Johnson Pass Apt. 567, South Jamesfurt, M...        Reviewed
# 2  9082 Anna Villages Apt. 511, Port Juanshire, V...          Closed
# 3  86578 Lawson Park Suite 865, South Brianfurt, ...          Closed
# 4       309 Roy Brook Apt. 282, Lake Scott, FL 84478          Closed
#
#   Most_Recent_Status       Source   Market                Street_Address  \
# 0             Closed     Internal  Chicago  875 Davis Overpass Suite 394
# 1          Cancelled  Auction.com   Dallas    1159 Johnson Pass Apt. 567
# ...

# %%
df2
# Out:
#                Column Name Target Table
# 0           Property_Title     property
# 1                  Address     property
# 2          Reviewed_Status        Leads
# 3       Most_Recent_Status        Leads
# 4                   Source        Leads
# ..                     ...          ...
# 61          Selling_Reason        leads
# 62  Seller_Retained_Broker        leads
# 63                HOA_Flag          HOA
# 64          Final_Reviewer        leads
# 65          School_Average     property
#
# [66 rows x 2 columns]

# %%
g_df= df2.groupby('Target Table')['Column Name'].count()

# %%
g_df
# Out:
# Target Table
# HOA           2
# Leads         6
# Rehab        13
# Taxes         1
# Valuation     9
# leads         3
# property     32
# Name: Column Name, dtype: int64

# %%
table_columns = df2.groupby('Target Table')['Column Name'].apply(list)

# %%
print(table_columns)
# Out:
# Target Table
# HOA                                            [HOA, HOA_Flag]
# Leads        [Reviewed_Status, Most_Recent_Status, Source, ...
# Rehab        [Underwriting_Rehab, Rehab_Calculation, Paint,...
# Taxes                                                  [Taxes]
# Valuation    [Previous_Rent, List_Price, Zestimate, ARV, Ex...
# leads        [Selling_Reason, Seller_Retained_Broker, Final...
# property     [Property_Title, Address, Market, Flood, Stree...
# Name: Column Name, dtype: object

# %%
property_cols = table_columns['property']

# %%
property_cols
# Out:
# ['Property_Title',
#  'Address',
#  'Market',
#  'Flood',
#  'Street_Address',
#  'City',
#  'State',
#  'Zip',
#  'Property_Type',
#  'Highway',
#  'Train',
#  'Tax_Rate',
#  'SQFT_Basement',
#  'HTW',
#  'Pool',
#  'Commercial',
#  'Water',
#  'Sewage',
#  'Year_Built',
#  'SQFT_MU',
#  'SQFT_Total',
#  'Parking',
#  'Bed',
#  'Bath',
#  'BasementYesNo',
#  'Layout',
#  'Rent_Restricted',
#  'Neighborhood_Rating',
#  'Latitude',
#  'Longitude',
#  'Subdivision',
#  'School_Average']

# %%
common_cols = [col for col in filter_df.columns if col in property_cols]

# %%
p_df= filter_df.loc[:, common_cols]

# %%
p_df
# Out:
#                                          Property_Title  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...
# 3     86578 Lawson Park Suite 865, South Brianfurt, ...
# 4          309 Roy Brook Apt. 282, Lake Scott, FL 84478
# ...                                                 ...
# 9995           139 Fisher Spur, North Brandon, WA 23114
# 9996       275 Gutierrez Views, Lake Victoria, WY 63275
# 9997        341 Vanessa Harbor, North Melissa, CT 39313
# 9998  78647 Brittany Village, North Ethanborough, NY...
# 9999  5461 Nichols Throughway, East Crystalborough, ...
#
#                                                 Address   Market  \
# 0     875 Davis Overpass Suite 394, South Kathrynsid...  Chicago
# 1     1159 Johnson Pass Apt. 567, South Jamesfurt, M...   Dallas
# 2     9082 Anna Villages Apt. 511, Port Juanshire, V...    Tampa
# ...

# %%
leads_cols = table_columns['Leads']
leads_cols
# Out:
# ['Reviewed_Status',
#  'Most_Recent_Status',
#  'Source',
#  'Occupancy',
#  'Net_Yield',
#  'IRR']

# %%
l_col = [col for col in filter_df.columns if col in leads_cols]

# %%
l_df= filter_df.loc[:, l_col]

# %%
l_df
# Out:
#      Reviewed_Status Most_Recent_Status       Source  Net_Yield    IRR
# 0             Closed             Closed     Internal       3.53  14.48
# 1           Reviewed          Cancelled  Auction.com       6.59  22.92
# 2             Closed            Pending     Opendoor       5.24  21.17
# 3             Closed          Cancelled       M.L.S.       9.65  14.12
# 4             Closed          Cancelled       M.L.S.       2.88  17.24
# ...              ...                ...          ...        ...    ...
# 9995         Offered            Pending         Bulk      17.28  24.05
# 9996        Reviewed             Close         M L S      10.41  17.38
# 9997          Closed        Always Kick         Bulk      13.49  12.07
# 9998         Offered             Cancel          MLS       2.65  19.47
# 9999       Cancelled          Cancelled        M L S       5.46  28.37
#
# [10000 rows x 5 columns]

# %%
HOA_cols = table_columns['HOA']

# %%
h_col = [col for col in filter_df.columns if col in HOA_cols]

# %%
h_df= filter_df.loc[:, h_col]

# %%
h_df
# Out:
#                                                     HOA
# 0     [{'HOA': 460, 'HOA_Flag': 'No'}, {'HOA': 476, ...
# 1     [{'HOA': 322, 'HOA_Flag': 'Yes'}, {'HOA': 219,...
# 2     [{'HOA': 242, 'HOA_Flag': 'Yes'}, {'HOA': 470,...
# 3                     [{'HOA': 500, 'HOA_Flag': 'Yes'}]
# 4     [{'HOA': 197, 'HOA_Flag': 'Yes'}, {'HOA': 424,...
# ...                                                 ...
# 9995                   [{'HOA': 417, 'HOA_Flag': 'No'}]
# 9996  [{'HOA': 103, 'HOA_Flag': 'No'}, {'HOA': 334, ...
# 9997                                                 []
# 9998  [{'HOA': 461, 'HOA_Flag': 'Yes'}, {'HOA': 469,...
# 9999  [{'HOA': 18, 'HOA_Flag': 'No'}, {'HOA': 170, '...
#
# [10000 rows x 1 columns]

# %%
sl_cols = table_columns['leads']

# %%
sl_col = [col for col in filter_df.columns if col in sl_cols]

# %%
sl_df= filter_df.loc[:, sl_col]

# %%
sl_df
# Out:
#      Selling_Reason   Final_Reviewer
# 0        Downsizing     Jason Miller
# 1     Investor Sale      Luis Garcia
# 2     Investor Sale  Samantha Pierce
# 3      Job Transfer  Samantha Pierce
# 4     Investor Sale     Priya Sharma
# ...             ...              ...
# 9995  Investor Sale   David Thompson
# 9996  Investor Sale  Sophia Williams
# 9997  Investor Sale     Jason Miller
# 9998  Investor Sale  Samantha Pierce
# 9999     Downsizing      Emily Patel
#
# [10000 rows x 2 columns]

# %%
sl_df.to_csv('small_leads.csv', index=False)

# %%
h_df.to_csv('HOA.csv', index=False)

# %%
l_df.to_csv('bigLeads.csv', index=False)

# %%
p_df.to_csv('Property.csv', index=False)

# %%
sl_df.columns
# Out:
# Index(['Selling_Reason', 'Final_Reviewer'], dtype='object')

# %%
l_df.columns
# Out:
# Index(['Reviewed_Status', 'Most_Recent_Status', 'Source', 'Net_Yield', 'IRR'], dtype='object')

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HOA     10000 non-null  object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %%
# !pip install mysql-connector-python
# Out:
# ...
#      |████████████████████████████████| 372 kB 136 kB/s eta 0:00:01
# ...

# %%
df_expanded = pd.concat([h_df.drop('HOA', axis=1), df['HOA'].apply(pd.Series)], axis=1)
df_expanded.head()
# Out:
#                                  0                                1
# 0   {'HOA': 460, 'HOA_Flag': 'No'}  {'HOA': 476, 'HOA_Flag': 'Yes'}
# 1  {'HOA': 322, 'HOA_Flag': 'Yes'}  {'HOA': 219, 'HOA_Flag': 'Yes'}
# 2  {'HOA': 242, 'HOA_Flag': 'Yes'}  {'HOA': 470, 'HOA_Flag': 'Yes'}
# 3  {'HOA': 500, 'HOA_Flag': 'Yes'}                              NaN
# 4  {'HOA': 197, 'HOA_Flag': 'Yes'}  {'HOA': 424, 'HOA_Flag': 'Yes'}

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HOA     10000 non-null  object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %%
df_exploded = h_df.explode('HOA').reset_index(drop=True)
print(df_exploded)
# Out:
#                                    HOA
# 0       {'HOA': 460, 'HOA_Flag': 'No'}
# 1      {'HOA': 476, 'HOA_Flag': 'Yes'}
# 2      {'HOA': 322, 'HOA_Flag': 'Yes'}
# 3      {'HOA': 219, 'HOA_Flag': 'Yes'}
# 4      {'HOA': 242, 'HOA_Flag': 'Yes'}
# ...                                ...
# 13324                              NaN
# 13325  {'HOA': 461, 'HOA_Flag': 'Yes'}
# 13326  {'HOA': 469, 'HOA_Flag': 'Yes'}
# 13327    {'HOA': 18, 'HOA_Flag': 'No'}
# 13328  {'HOA': 170, 'HOA_Flag': 'Yes'}
#
# [13329 rows x 1 columns]

# %%
import pandas as pd


df_exploded2 = h_df.explode('HOA').reset_index(drop=True)
df_exploded2.head()
# Out:
#                                HOA
# 0   {'HOA': 460, 'HOA_Flag': 'No'}
# 1  {'HOA': 476, 'HOA_Flag': 'Yes'}
# 2  {'HOA': 322, 'HOA_Flag': 'Yes'}
# 3  {'HOA': 219, 'HOA_Flag': 'Yes'}
# 4  {'HOA': 242, 'HOA_Flag': 'Yes'}

# %%
df_normalized = pd.concat(
    [df_exploded2.drop('HOA', axis=1), df_exploded2['HOA'].apply(pd.Series)],
    axis=1
)

# %%
df_normalized.isnull().sum()
# Out:
# HOA          3336
# HOA_Flag     3336
# 0           13329
# dtype: int64

# %%
df_normalized.columns
# Out:
# Index(['HOA', 'HOA_Flag', 0], dtype='object')

# %%
df_normalized = df_normalized.drop(columns=[0])

# %%
df_normalized
# Out:
#          HOA HOA_Flag
# 0      460.0       No
# 1      476.0      Yes
# 2      322.0      Yes
# 3      219.0      Yes
# 4      242.0      Yes
# ...      ...      ...
# 13324    NaN      NaN
# 13325  461.0      Yes
# 13326  469.0      Yes
# 13327   18.0       No
# 13328  170.0      Yes
#
# [13329 rows x 2 columns]

# %%
hoa_df=df_normalized.fillna(method='ffill')

# %%
rehab_cols = table_columns['Taxes']

# %%
Taxes = [col for col in filter_df.columns if col in rehab_cols]

# %%
Taxes= filter_df.loc[:, r_col]

# %%
Taxes
# Out:
#       Taxes
# 0      6389
# 1      9321
# 2      9963
# 3      2173
# 4      5985
# ...     ...
# 9995   4822
# 9996   4850
# 9997   8370
# 9998   9005
# 9999   5199
#
# [10000 rows x 1 columns]

# %%
hoa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13329 entries, 0 to 13328
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HOA       13329 non-null  float64
#  1   HOA_Flag  13329 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 208.4+ KB

# %%
l_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Reviewed_Status     10000 non-null  object
#  1   Most_Recent_Status  10000 non-null  object
#  2   Source              10000 non-null  object
#  3   Net_Yield           10000 non-null  float64
#  4   IRR                 10000 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 390.8+ KB

# %%
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='harsh',
    password='Harsh@1234',
    database='properties_db'
)
cursor = conn.cursor()

# %%
for _, row in hoa_df.iterrows():
    cursor.execute("""
        INSERT INTO hoa_details (property_id, HOA, HOA_Flag)
        VALUES (%s, %s, %s)
    """, (row.get('property_id'), row['HOA'], row['HOA_Flag']))
conn.commit()

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[411], line 2
#       1 for row in df_property.itertuples(index=False, name=None):
# ----> 2     cursor.execute("""
#       3         INSERT INTO property_details (
#       4             Property_Title, Address, Market, Street_Address, City, State, Zip,
#       5             Property_Type, Tax_Rate, SQFT_Basement, Year_Built, SQFT_MU, SQFT_Total,
#       6             Parking, Bed, Bath, Layout, Neighborhood_Rating, Latitude, Longitude,
#       7             Subdivision, School_Average
#       8         ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#       9     """, row)
#      11 conn.commit()
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor.py:522, in MySQLCursor.execute(self, operation, params, multi)
# ...

# %%
for row in p_df.itertuples(index=False, name=None):
    cursor.execute("""
        INSERT INTO property_details (
            Property_Title, Address, Market, Street_Address, City, State, Zip,
            Property_Type, Tax_Rate, SQFT_Basement, Year_Built, SQFT_MU, SQFT_Total,
            Parking, Bed, Bath, Layout, Neighborhood_Rating, Latitude, Longitude,
            Subdivision, School_Average
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, row)

conn.commit()
